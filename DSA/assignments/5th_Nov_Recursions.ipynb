# %% [markdown]
# ### Question-01: Tower of hanoi

# %%
def tower_of_hanoi(n, source, auxillary, target):
    """
    Solves the Tower of Hanoi problem using recursion.

    Args:
        n: Number of disks to move.
        source: Source Rod
        auxillary: Auxillary Rod
        target: Target Rod
        
    Returns: List of moves
    """
    moves = []
    
    def hanoi_recursive(n, source, auxillary, target):
        if n==1:
            #Base case: Move the smallest disk directly from source to target
            moves.append(f"Move disk 1 from {source} to {target}")
            return 
        
        # Step 1: Move n-1 disks from source to auxiliary using target as the auxiliary
        hanoi_recursive(n-1, source, target, auxillary)
        
        # Step 2: Move the nth disk from source to target
        moves.append(f"Move disk {n} from {source} to {target}")
        
        # Step 3: Move the n-1 disks from auxiliary to target using source as the auxiliary
        hanoi_recursive(n-1, auxillary, source, target)
        
    hanoi_recursive(n, source, auxillary, target)
    return moves


# Testing the Tower of Hanoi algorithm with 3 disks
n = 10
source = 'A'
auxiliary = 'B'
target = 'C'

print("Question 1: Tower of Hanoi Solution")
print(f"Moving {n} disks from {source} to {target} using {auxiliary} as auxiliary:")
moves = tower_of_hanoi(n, source, auxiliary, target)
for i, move in enumerate(moves, 1):
    print(f"Step {i}: {move}")
# Out:
# Question 1: Tower of Hanoi Solution
# Moving 10 disks from A to C using B as auxiliary:
# Step 1: Move disk 1 from A to B
# Step 2: Move disk 2 from A to C
# Step 3: Move disk 1 from B to C
# Step 4: Move disk 3 from A to B
# Step 5: Move disk 1 from C to A
# Step 6: Move disk 2 from C to B
# Step 7: Move disk 1 from A to B
# Step 8: Move disk 4 from A to C
# Step 9: Move disk 1 from B to C
# Step 10: Move disk 2 from B to A
# Step 11: Move disk 1 from C to A
# Step 12: Move disk 3 from B to C
# Step 13: Move disk 1 from A to B
# Step 14: Move disk 2 from A to C
# Step 15: Move disk 1 from B to C
# Step 16: Move disk 5 from A to B
# Step 17: Move disk 1 from C to A
# Step 18: Move disk 2 from C to B
# Step 19: Move disk 1 from A to B
# Step 20: Move disk 3 from C to A
# Step 21: Move disk 1 from B to C
# Step 22: Move disk 2 from B to A
# Step 23: Move disk 1 from C to A
# Step 24: Move disk 4 from C to B
# Step 25: Move disk 1 from A to B
# Step 26: Move disk 2 from A to C
# Step 27: Move disk 1 from B to C
# Step 28: Move disk 3 from A to B
# Step 29: Move disk 1 from C to A
# Step 30: Move disk 2 from C to B
# Step 31: Move disk 1 from A to B
# Step 32: Move disk 6 from A to C
# Step 33: Move disk 1 from B to C
# Step 34: Move disk 2 from B to A
# Step 35: Move disk 1 from C to A
# Step 36: Move disk 3 from B to C
# Step 37: Move disk 1 from A to B
# Step 38: Move disk 2 from A to C
# Step 39: Move disk 1 from B to C
# Step 40: Move disk 4 from B to A
# Step 41: Move disk 1 from C to A
# Step 42: Move disk 2 from C to B
# Step 43: Move disk 1 from A to B
# Step 44: Move disk 3 from C to A
# Step 45: Move disk 1 from B to C
# Step 46: Move disk 2 from B to A
# Step 47: Move disk 1 from C to A
# Step 48: Move disk 5 from B to C
# Step 49: Move disk 1 from A to B
# Step 50: Move disk 2 from A to C
# Step 51: Move disk 1 from B to C
# Step 52: Move disk 3 from A to B
# Step 53: Move disk 1 from C to A
# Step 54: Move disk 2 from C to B
# Step 55: Move disk 1 from A to B
# Step 56: Move disk 4 from A to C
# Step 57: Move disk 1 from B to C
# Step 58: Move disk 2 from B to A
# Step 59: Move disk 1 from C to A
# Step 60: Move disk 3 from B to C
# Step 61: Move disk 1 from A to B
# Step 62: Move disk 2 from A to C
# Step 63: Move disk 1 from B to C
# Step 64: Move disk 7 from A to B
# Step 65: Move disk 1 from C to A
# Step 66: Move disk 2 from C to B
# Step 67: Move disk 1 from A to B
# Step 68: Move disk 3 from C to A
# Step 69: Move disk 1 from B to C
# Step 70: Move disk 2 from B to A
# Step 71: Move disk 1 from C to A
# Step 72: Move disk 4 from C to B
# Step 73: Move disk 1 from A to B
# Step 74: Move disk 2 from A to C
# Step 75: Move disk 1 from B to C
# Step 76: Move disk 3 from A to B
# Step 77: Move disk 1 from C to A
# Step 78: Move disk 2 from C to B
# Step 79: Move disk 1 from A to B
# Step 80: Move disk 5 from C to A
# Step 81: Move disk 1 from B to C
# Step 82: Move disk 2 from B to A
# Step 83: Move disk 1 from C to A
# Step 84: Move disk 3 from B to C
# Step 85: Move disk 1 from A to B
# Step 86: Move disk 2 from A to C
# Step 87: Move disk 1 from B to C
# Step 88: Move disk 4 from B to A
# Step 89: Move disk 1 from C to A
# Step 90: Move disk 2 from C to B
# Step 91: Move disk 1 from A to B
# Step 92: Move disk 3 from C to A
# Step 93: Move disk 1 from B to C
# Step 94: Move disk 2 from B to A
# Step 95: Move disk 1 from C to A
# Step 96: Move disk 6 from C to B
# Step 97: Move disk 1 from A to B
# Step 98: Move disk 2 from A to C
# Step 99: Move disk 1 from B to C
# Step 100: Move disk 3 from A to B
# Step 101: Move disk 1 from C to A
# Step 102: Move disk 2 from C to B
# Step 103: Move disk 1 from A to B
# Step 104: Move disk 4 from A to C
# Step 105: Move disk 1 from B to C
# Step 106: Move disk 2 from B to A
# Step 107: Move disk 1 from C to A
# Step 108: Move disk 3 from B to C
# Step 109: Move disk 1 from A to B
# Step 110: Move disk 2 from A to C
# Step 111: Move disk 1 from B to C
# Step 112: Move disk 5 from A to B
# Step 113: Move disk 1 from C to A
# Step 114: Move disk 2 from C to B
# Step 115: Move disk 1 from A to B
# Step 116: Move disk 3 from C to A
# Step 117: Move disk 1 from B to C
# Step 118: Move disk 2 from B to A
# Step 119: Move disk 1 from C to A
# Step 120: Move disk 4 from C to B
# Step 121: Move disk 1 from A to B
# Step 122: Move disk 2 from A to C
# Step 123: Move disk 1 from B to C
# Step 124: Move disk 3 from A to B
# Step 125: Move disk 1 from C to A
# Step 126: Move disk 2 from C to B
# Step 127: Move disk 1 from A to B
# Step 128: Move disk 8 from A to C
# Step 129: Move disk 1 from B to C
# Step 130: Move disk 2 from B to A
# Step 131: Move disk 1 from C to A
# Step 132: Move disk 3 from B to C
# Step 133: Move disk 1 from A to B
# Step 134: Move disk 2 from A to C
# Step 135: Move disk 1 from B to C
# Step 136: Move disk 4 from B to A
# Step 137: Move disk 1 from C to A
# Step 138: Move disk 2 from C to B
# Step 139: Move disk 1 from A to B
# Step 140: Move disk 3 from C to A
# Step 229: Move disk 1 from A to B
# Step 230: Move disk 2 from A to C
# Step 231: Move disk 1 from B to C
# Step 232: Move disk 4 from B to A
# Step 233: Move disk 1 from C to A
# Step 234: Move disk 2 from C to B
# Step 235: Move disk 1 from A to B
# Step 236: Move disk 3 from C to A
# Step 237: Move disk 1 from B to C
# Step 238: Move disk 2 from B to A
# Step 239: Move disk 1 from C to A
# Step 240: Move disk 5 from B to C
# Step 241: Move disk 1 from A to B
# Step 242: Move disk 2 from A to C
# Step 243: Move disk 1 from B to C
# Step 244: Move disk 3 from A to B
# Step 245: Move disk 1 from C to A
# Step 246: Move disk 2 from C to B
# Step 247: Move disk 1 from A to B
# Step 248: Move disk 4 from A to C
# Step 249: Move disk 1 from B to C
# Step 250: Move disk 2 from B to A
# Step 251: Move disk 1 from C to A
# Step 252: Move disk 3 from B to C
# Step 253: Move disk 1 from A to B
# Step 254: Move disk 2 from A to C
# Step 255: Move disk 1 from B to C
# Step 256: Move disk 9 from A to B
# Step 257: Move disk 1 from C to A
# Step 258: Move disk 2 from C to B
# Step 259: Move disk 1 from A to B
# Step 260: Move disk 3 from C to A
# Step 261: Move disk 1 from B to C
# Step 262: Move disk 2 from B to A
# Step 263: Move disk 1 from C to A
# Step 264: Move disk 4 from C to B
# Step 265: Move disk 1 from A to B
# Step 266: Move disk 2 from A to C
# Step 267: Move disk 1 from B to C
# Step 268: Move disk 3 from A to B
# Step 269: Move disk 1 from C to A
# Step 270: Move disk 2 from C to B
# Step 271: Move disk 1 from A to B
# Step 272: Move disk 5 from C to A
# Step 273: Move disk 1 from B to C
# Step 274: Move disk 2 from B to A
# Step 275: Move disk 1 from C to A
# Step 276: Move disk 3 from B to C
# Step 277: Move disk 1 from A to B
# Step 278: Move disk 2 from A to C
# Step 279: Move disk 1 from B to C
# Step 280: Move disk 4 from B to A
# Step 281: Move disk 1 from C to A
# Step 282: Move disk 2 from C to B
# Step 283: Move disk 1 from A to B
# Step 284: Move disk 3 from C to A
# Step 285: Move disk 1 from B to C
# Step 286: Move disk 2 from B to A
# Step 287: Move disk 1 from C to A
# Step 288: Move disk 6 from C to B
# Step 289: Move disk 1 from A to B
# Step 290: Move disk 2 from A to C
# Step 291: Move disk 1 from B to C
# Step 292: Move disk 3 from A to B
# Step 293: Move disk 1 from C to A
# Step 294: Move disk 2 from C to B
# Step 295: Move disk 1 from A to B
# Step 296: Move disk 4 from A to C
# Step 297: Move disk 1 from B to C
# Step 298: Move disk 2 from B to A
# Step 299: Move disk 1 from C to A
# Step 300: Move disk 3 from B to C
# Step 301: Move disk 1 from A to B
# Step 302: Move disk 2 from A to C
# Step 303: Move disk 1 from B to C
# Step 304: Move disk 5 from A to B
# Step 305: Move disk 1 from C to A
# Step 306: Move disk 2 from C to B
# Step 307: Move disk 1 from A to B
# Step 308: Move disk 3 from C to A
# Step 309: Move disk 1 from B to C
# Step 310: Move disk 2 from B to A
# Step 311: Move disk 1 from C to A
# Step 312: Move disk 4 from C to B
# Step 313: Move disk 1 from A to B
# Step 314: Move disk 2 from A to C
# Step 315: Move disk 1 from B to C
# Step 316: Move disk 3 from A to B
# Step 493: Move disk 1 from A to B
# Step 494: Move disk 2 from A to C
# Step 495: Move disk 1 from B to C
# Step 496: Move disk 5 from A to B
# Step 497: Move disk 1 from C to A
# Step 498: Move disk 2 from C to B
# Step 499: Move disk 1 from A to B
# Step 500: Move disk 3 from C to A
# Step 501: Move disk 1 from B to C
# Step 502: Move disk 2 from B to A
# Step 503: Move disk 1 from C to A
# Step 504: Move disk 4 from C to B
# Step 505: Move disk 1 from A to B
# Step 506: Move disk 2 from A to C
# Step 507: Move disk 1 from B to C
# Step 508: Move disk 3 from A to B
# Step 509: Move disk 1 from C to A
# Step 510: Move disk 2 from C to B
# Step 511: Move disk 1 from A to B
# Step 512: Move disk 10 from A to C
# Step 513: Move disk 1 from B to C
# Step 514: Move disk 2 from B to A
# Step 515: Move disk 1 from C to A
# Step 516: Move disk 3 from B to C
# Step 517: Move disk 1 from A to B
# Step 518: Move disk 2 from A to C
# Step 519: Move disk 1 from B to C
# Step 520: Move disk 4 from B to A
# Step 521: Move disk 1 from C to A
# Step 522: Move disk 2 from C to B
# Step 523: Move disk 1 from A to B
# Step 524: Move disk 3 from C to A
# Step 525: Move disk 1 from B to C
# Step 526: Move disk 2 from B to A
# Step 527: Move disk 1 from C to A
# Step 528: Move disk 5 from B to C
# Step 529: Move disk 1 from A to B
# Step 530: Move disk 2 from A to C
# Step 531: Move disk 1 from B to C
# Step 532: Move disk 3 from A to B
# Step 533: Move disk 1 from C to A
# Step 534: Move disk 2 from C to B
# Step 535: Move disk 1 from A to B
# Step 536: Move disk 4 from A to C
# Step 537: Move disk 1 from B to C
# Step 538: Move disk 2 from B to A
# Step 539: Move disk 1 from C to A
# Step 540: Move disk 3 from B to C
# Step 541: Move disk 1 from A to B
# Step 542: Move disk 2 from A to C
# Step 543: Move disk 1 from B to C
# Step 544: Move disk 6 from B to A
# Step 545: Move disk 1 from C to A
# Step 546: Move disk 2 from C to B
# Step 547: Move disk 1 from A to B
# Step 548: Move disk 3 from C to A
# Step 549: Move disk 1 from B to C
# Step 550: Move disk 2 from B to A
# Step 551: Move disk 1 from C to A
# Step 552: Move disk 4 from C to B
# Step 553: Move disk 1 from A to B
# Step 554: Move disk 2 from A to C
# Step 555: Move disk 1 from B to C
# Step 556: Move disk 3 from A to B
# Step 557: Move disk 1 from C to A
# Step 558: Move disk 2 from C to B
# Step 559: Move disk 1 from A to B
# Step 560: Move disk 5 from C to A
# Step 561: Move disk 1 from B to C
# Step 562: Move disk 2 from B to A
# Step 563: Move disk 1 from C to A
# Step 564: Move disk 3 from B to C
# Step 565: Move disk 1 from A to B
# Step 566: Move disk 2 from A to C
# Step 567: Move disk 1 from B to C
# Step 568: Move disk 4 from B to A
# Step 569: Move disk 1 from C to A
# Step 570: Move disk 2 from C to B
# Step 571: Move disk 1 from A to B
# Step 572: Move disk 3 from C to A
# Step 573: Move disk 1 from B to C
# Step 574: Move disk 2 from B to A
# Step 575: Move disk 1 from C to A
# Step 576: Move disk 7 from B to C
# Step 577: Move disk 1 from A to B
# Step 578: Move disk 2 from A to C
# Step 579: Move disk 1 from B to C
# Step 580: Move disk 3 from A to B
# Step 669: Move disk 1 from B to C
# Step 670: Move disk 2 from B to A
# Step 671: Move disk 1 from C to A
# Step 672: Move disk 6 from C to B
# Step 673: Move disk 1 from A to B
# Step 674: Move disk 2 from A to C
# Step 675: Move disk 1 from B to C
# Step 676: Move disk 3 from A to B
# Step 677: Move disk 1 from C to A
# Step 678: Move disk 2 from C to B
# Step 679: Move disk 1 from A to B
# Step 680: Move disk 4 from A to C
# Step 681: Move disk 1 from B to C
# Step 682: Move disk 2 from B to A
# Step 683: Move disk 1 from C to A
# Step 684: Move disk 3 from B to C
# Step 685: Move disk 1 from A to B
# Step 686: Move disk 2 from A to C
# Step 687: Move disk 1 from B to C
# Step 688: Move disk 5 from A to B
# Step 689: Move disk 1 from C to A
# Step 690: Move disk 2 from C to B
# Step 691: Move disk 1 from A to B
# Step 692: Move disk 3 from C to A
# Step 693: Move disk 1 from B to C
# Step 694: Move disk 2 from B to A
# Step 695: Move disk 1 from C to A
# Step 696: Move disk 4 from C to B
# Step 697: Move disk 1 from A to B
# Step 698: Move disk 2 from A to C
# Step 699: Move disk 1 from B to C
# Step 700: Move disk 3 from A to B
# Step 701: Move disk 1 from C to A
# Step 702: Move disk 2 from C to B
# Step 703: Move disk 1 from A to B
# Step 704: Move disk 7 from C to A
# Step 705: Move disk 1 from B to C
# Step 706: Move disk 2 from B to A
# Step 707: Move disk 1 from C to A
# Step 708: Move disk 3 from B to C
# Step 709: Move disk 1 from A to B
# Step 710: Move disk 2 from A to C
# Step 711: Move disk 1 from B to C
# Step 712: Move disk 4 from B to A
# Step 713: Move disk 1 from C to A
# Step 714: Move disk 2 from C to B
# Step 715: Move disk 1 from A to B
# Step 716: Move disk 3 from C to A
# Step 717: Move disk 1 from B to C
# Step 718: Move disk 2 from B to A
# Step 719: Move disk 1 from C to A
# Step 720: Move disk 5 from B to C
# Step 721: Move disk 1 from A to B
# Step 722: Move disk 2 from A to C
# Step 723: Move disk 1 from B to C
# Step 724: Move disk 3 from A to B
# Step 725: Move disk 1 from C to A
# Step 726: Move disk 2 from C to B
# Step 727: Move disk 1 from A to B
# Step 728: Move disk 4 from A to C
# Step 729: Move disk 1 from B to C
# Step 730: Move disk 2 from B to A
# Step 731: Move disk 1 from C to A
# Step 732: Move disk 3 from B to C
# Step 733: Move disk 1 from A to B
# Step 734: Move disk 2 from A to C
# Step 735: Move disk 1 from B to C
# Step 736: Move disk 6 from B to A
# Step 737: Move disk 1 from C to A
# Step 738: Move disk 2 from C to B
# Step 739: Move disk 1 from A to B
# Step 740: Move disk 3 from C to A
# Step 741: Move disk 1 from B to C
# Step 742: Move disk 2 from B to A
# Step 743: Move disk 1 from C to A
# Step 744: Move disk 4 from C to B
# Step 745: Move disk 1 from A to B
# Step 746: Move disk 2 from A to C
# Step 747: Move disk 1 from B to C
# Step 748: Move disk 3 from A to B
# Step 749: Move disk 1 from C to A
# Step 750: Move disk 2 from C to B
# Step 751: Move disk 1 from A to B
# Step 752: Move disk 5 from C to A
# Step 753: Move disk 1 from B to C
# Step 754: Move disk 2 from B to A
# Step 755: Move disk 1 from C to A
# Step 756: Move disk 3 from B to C
# Step 757: Move disk 1 from A to B
# Step 758: Move disk 2 from A to C
# Step 759: Move disk 1 from B to C
# Step 760: Move disk 4 from B to A
# Step 761: Move disk 1 from C to A
# Step 762: Move disk 2 from C to B
# Step 763: Move disk 1 from A to B
# Step 764: Move disk 3 from C to A
# Step 765: Move disk 1 from B to C
# Step 766: Move disk 2 from B to A
# Step 767: Move disk 1 from C to A
# Step 768: Move disk 9 from B to C
# Step 769: Move disk 1 from A to B
# Step 770: Move disk 2 from A to C
# Step 771: Move disk 1 from B to C
# Step 772: Move disk 3 from A to B
# Step 773: Move disk 1 from C to A
# Step 774: Move disk 2 from C to B
# Step 775: Move disk 1 from A to B
# Step 776: Move disk 4 from A to C
# Step 777: Move disk 1 from B to C
# Step 778: Move disk 2 from B to A
# Step 779: Move disk 1 from C to A
# Step 780: Move disk 3 from B to C
# Step 781: Move disk 1 from A to B
# Step 782: Move disk 2 from A to C
# Step 783: Move disk 1 from B to C
# Step 784: Move disk 5 from A to B
# Step 785: Move disk 1 from C to A
# Step 786: Move disk 2 from C to B
# Step 787: Move disk 1 from A to B
# Step 788: Move disk 3 from C to A
# Step 789: Move disk 1 from B to C
# Step 790: Move disk 2 from B to A
# Step 791: Move disk 1 from C to A
# Step 792: Move disk 4 from C to B
# Step 793: Move disk 1 from A to B
# Step 794: Move disk 2 from A to C
# Step 795: Move disk 1 from B to C
# Step 796: Move disk 3 from A to B
# Step 797: Move disk 1 from C to A
# Step 798: Move disk 2 from C to B
# Step 799: Move disk 1 from A to B
# Step 800: Move disk 6 from A to C
# Step 801: Move disk 1 from B to C
# Step 802: Move disk 2 from B to A
# Step 803: Move disk 1 from C to A
# Step 804: Move disk 3 from B to C
# Step 805: Move disk 1 from A to B
# Step 806: Move disk 2 from A to C
# Step 807: Move disk 1 from B to C
# Step 808: Move disk 4 from B to A
# Step 809: Move disk 1 from C to A
# Step 810: Move disk 2 from C to B
# Step 811: Move disk 1 from A to B
# Step 812: Move disk 3 from C to A
# Step 813: Move disk 1 from B to C
# Step 814: Move disk 2 from B to A
# Step 815: Move disk 1 from C to A
# Step 816: Move disk 5 from B to C
# Step 817: Move disk 1 from A to B
# Step 818: Move disk 2 from A to C
# Step 819: Move disk 1 from B to C
# Step 820: Move disk 3 from A to B
# Step 821: Move disk 1 from C to A
# Step 822: Move disk 2 from C to B
# Step 823: Move disk 1 from A to B
# Step 824: Move disk 4 from A to C
# Step 825: Move disk 1 from B to C
# Step 826: Move disk 2 from B to A
# Step 827: Move disk 1 from C to A
# Step 828: Move disk 3 from B to C
# Step 829: Move disk 1 from A to B
# Step 830: Move disk 2 from A to C
# Step 831: Move disk 1 from B to C
# Step 832: Move disk 7 from A to B
# Step 833: Move disk 1 from C to A
# Step 834: Move disk 2 from C to B
# Step 835: Move disk 1 from A to B
# Step 836: Move disk 3 from C to A
# Step 837: Move disk 1 from B to C
# Step 838: Move disk 2 from B to A
# Step 839: Move disk 1 from C to A
# Step 840: Move disk 4 from C to B
# Step 841: Move disk 1 from A to B
# Step 842: Move disk 2 from A to C
# Step 843: Move disk 1 from B to C
# Step 844: Move disk 3 from A to B
# Step 845: Move disk 1 from C to A
# Step 846: Move disk 2 from C to B
# Step 847: Move disk 1 from A to B
# Step 848: Move disk 5 from C to A
# Step 849: Move disk 1 from B to C
# Step 850: Move disk 2 from B to A
# Step 851: Move disk 1 from C to A
# Step 852: Move disk 3 from B to C
# Step 853: Move disk 1 from A to B
# Step 854: Move disk 2 from A to C
# Step 855: Move disk 1 from B to C
# Step 856: Move disk 4 from B to A
# Step 857: Move disk 1 from C to A
# Step 858: Move disk 2 from C to B
# Step 859: Move disk 1 from A to B
# Step 860: Move disk 3 from C to A
# Step 861: Move disk 1 from B to C
# Step 862: Move disk 2 from B to A
# Step 863: Move disk 1 from C to A
# Step 864: Move disk 6 from C to B
# Step 865: Move disk 1 from A to B
# Step 866: Move disk 2 from A to C
# Step 867: Move disk 1 from B to C
# Step 868: Move disk 3 from A to B
# Step 869: Move disk 1 from C to A
# Step 870: Move disk 2 from C to B
# Step 871: Move disk 1 from A to B
# Step 872: Move disk 4 from A to C
# Step 873: Move disk 1 from B to C
# Step 874: Move disk 2 from B to A
# Step 875: Move disk 1 from C to A
# Step 876: Move disk 3 from B to C
# Step 877: Move disk 1 from A to B
# Step 878: Move disk 2 from A to C
# Step 879: Move disk 1 from B to C
# Step 880: Move disk 5 from A to B
# Step 881: Move disk 1 from C to A
# Step 882: Move disk 2 from C to B
# Step 883: Move disk 1 from A to B
# Step 884: Move disk 3 from C to A
# Step 885: Move disk 1 from B to C
# Step 886: Move disk 2 from B to A
# Step 887: Move disk 1 from C to A
# Step 888: Move disk 4 from C to B
# Step 889: Move disk 1 from A to B
# Step 890: Move disk 2 from A to C
# Step 891: Move disk 1 from B to C
# Step 892: Move disk 3 from A to B
# Step 893: Move disk 1 from C to A
# Step 894: Move disk 2 from C to B
# Step 895: Move disk 1 from A to B
# Step 896: Move disk 8 from A to C
# Step 897: Move disk 1 from B to C
# Step 898: Move disk 2 from B to A
# Step 899: Move disk 1 from C to A
# Step 900: Move disk 3 from B to C
# Step 901: Move disk 1 from A to B
# Step 902: Move disk 2 from A to C
# Step 903: Move disk 1 from B to C
# Step 904: Move disk 4 from B to A
# Step 905: Move disk 1 from C to A
# Step 906: Move disk 2 from C to B
# Step 907: Move disk 1 from A to B
# Step 908: Move disk 3 from C to A
# Step 909: Move disk 1 from B to C
# Step 910: Move disk 2 from B to A
# Step 911: Move disk 1 from C to A
# Step 912: Move disk 5 from B to C
# Step 913: Move disk 1 from A to B
# Step 914: Move disk 2 from A to C
# Step 915: Move disk 1 from B to C
# Step 916: Move disk 3 from A to B
# Step 917: Move disk 1 from C to A
# Step 918: Move disk 2 from C to B
# Step 919: Move disk 1 from A to B
# Step 920: Move disk 4 from A to C
# Step 921: Move disk 1 from B to C
# Step 922: Move disk 2 from B to A
# Step 923: Move disk 1 from C to A
# Step 924: Move disk 3 from B to C
# Step 925: Move disk 1 from A to B
# Step 926: Move disk 2 from A to C
# Step 927: Move disk 1 from B to C
# Step 928: Move disk 6 from B to A
# Step 929: Move disk 1 from C to A
# Step 930: Move disk 2 from C to B
# Step 931: Move disk 1 from A to B
# Step 932: Move disk 3 from C to A
# Step 933: Move disk 1 from B to C
# Step 934: Move disk 2 from B to A
# Step 935: Move disk 1 from C to A
# Step 936: Move disk 4 from C to B
# Step 937: Move disk 1 from A to B
# Step 938: Move disk 2 from A to C
# Step 939: Move disk 1 from B to C
# Step 940: Move disk 3 from A to B
# Step 941: Move disk 1 from C to A
# Step 942: Move disk 2 from C to B
# Step 943: Move disk 1 from A to B
# Step 944: Move disk 5 from C to A
# Step 945: Move disk 1 from B to C
# Step 946: Move disk 2 from B to A
# Step 947: Move disk 1 from C to A
# Step 948: Move disk 3 from B to C
# Step 949: Move disk 1 from A to B
# Step 950: Move disk 2 from A to C
# Step 951: Move disk 1 from B to C
# Step 952: Move disk 4 from B to A
# Step 953: Move disk 1 from C to A
# Step 954: Move disk 2 from C to B
# Step 955: Move disk 1 from A to B
# Step 956: Move disk 3 from C to A
# Step 957: Move disk 1 from B to C
# Step 958: Move disk 2 from B to A
# Step 959: Move disk 1 from C to A
# Step 960: Move disk 7 from B to C
# Step 961: Move disk 1 from A to B
# Step 962: Move disk 2 from A to C
# Step 963: Move disk 1 from B to C
# Step 964: Move disk 3 from A to B
# Step 965: Move disk 1 from C to A
# Step 966: Move disk 2 from C to B
# Step 967: Move disk 1 from A to B
# Step 968: Move disk 4 from A to C
# Step 969: Move disk 1 from B to C
# Step 970: Move disk 2 from B to A
# Step 971: Move disk 1 from C to A
# Step 972: Move disk 3 from B to C
# Step 973: Move disk 1 from A to B
# Step 974: Move disk 2 from A to C
# Step 975: Move disk 1 from B to C
# Step 976: Move disk 5 from A to B
# Step 977: Move disk 1 from C to A
# Step 978: Move disk 2 from C to B
# Step 979: Move disk 1 from A to B
# Step 980: Move disk 3 from C to A
# Step 981: Move disk 1 from B to C
# Step 982: Move disk 2 from B to A
# Step 983: Move disk 1 from C to A
# Step 984: Move disk 4 from C to B
# Step 985: Move disk 1 from A to B
# Step 986: Move disk 2 from A to C
# Step 987: Move disk 1 from B to C
# Step 988: Move disk 3 from A to B
# Step 989: Move disk 1 from C to A
# Step 990: Move disk 2 from C to B
# Step 991: Move disk 1 from A to B
# Step 992: Move disk 6 from A to C
# Step 993: Move disk 1 from B to C
# Step 994: Move disk 2 from B to A
# Step 995: Move disk 1 from C to A
# Step 996: Move disk 3 from B to C
# Step 997: Move disk 1 from A to B
# Step 998: Move disk 2 from A to C
# Step 999: Move disk 1 from B to C
# Step 1000: Move disk 4 from B to A
# Step 1001: Move disk 1 from C to A
# Step 1002: Move disk 2 from C to B
# Step 1003: Move disk 1 from A to B
# Step 1004: Move disk 3 from C to A
# Step 1005: Move disk 1 from B to C
# Step 1006: Move disk 2 from B to A
# Step 1007: Move disk 1 from C to A
# Step 1008: Move disk 5 from B to C
# Step 1009: Move disk 1 from A to B
# Step 1010: Move disk 2 from A to C
# Step 1011: Move disk 1 from B to C
# Step 1012: Move disk 3 from A to B
# Step 1013: Move disk 1 from C to A
# Step 1014: Move disk 2 from C to B
# Step 1015: Move disk 1 from A to B
# Step 1016: Move disk 4 from A to C
# Step 1017: Move disk 1 from B to C
# Step 1018: Move disk 2 from B to A
# Step 1019: Move disk 1 from C to A
# Step 1020: Move disk 3 from B to C
# Step 1021: Move disk 1 from A to B
# Step 1022: Move disk 2 from A to C
# Step 1023: Move disk 1 from B to C

# %% [markdown]
# **Tower of Hanoi Algorithm Explanation**:
#
# The Tower of Hanoi is a classic recursive problem where we need to move n disks from a source rod to a target rod,
# using an auxiliary rod, following these rules:
# 1. Only one disk can be moved at a time.
# 2. A larger disk cannot be placed on top of a smaller disk.
# 3. Only the top disk from any rod can be moved.
#
# The recursive solution breaks down as follows:
# Base Case:
# - When n = 1, simply move the disk from source to target.
#
# Recursive Case (for n > 1):
# 1. Move n-1 disks from source to auxiliary using target as intermediate.
# 2. Move the nth disk (largest) from source to target.
# 3. Move n-1 disks from auxiliary to target using source as intermediate.
#
# This solution leverages the key insight that to move n disks, we must first solve the problem for n-1 disks.
# The time complexity is O(2^n) as each disk movement requires 2^n - 1 moves.
# Space complexity is O(n) due to the recursion call stack.
#
# Python Implementation Details:
# - We use a helper array to store the moves for demonstration purposes.
# - The recursive function captures the three steps of the algorithm clearly.
# - For n=3, the algorithm makes 7 moves (2^3 - 1).

# %% [markdown]
# ### Question-02: Given two strings word1 and word2, return the minimum number of operations required to convert word1 to word2.

# %% [markdown]
# **Example 1**:
# - Input: word1 = "horse", word2 = "ros"
# - Output: 3
# - Explanation:
#  - horse -> rorse (replace 'h' with 'r')
#  - rorse -> rose (remove 'r')
#  - rose -> ros (remove 'e')
#
# **Example 2**:
# - Input: word1 = "intention", word2 = "execution"
# - Output: 5
# - Explanation:
#  - intention -> inention (remove 't')
#  - inention -> enention (replace 'i' with 'e')
#  - enention -> exention (replace 'n' with 'x')
#  - exention -> exection (replace 'n' with 'c')
#  - exection -> execution (insert 'u')

# %%
def min_distance(word1, word2):
    """
    Calculates the minimum number of operations to convert word1 to word2.

    Args:
        word1: First string
        word2: Second string
    
    Returns: Minimum number of operations
    """
    
    cache = {}   ## Memoization cache
    
    def edit_distance_recursive(i, j):
        ## Base case
        if i==0:   ## # If word1 is empty, insert all characters of word2
            return j
        if j ==0:   ## # If word2 is empty, delete all characters of word1
            return i
        
        # Check if result already calculated
        if (i, j) in cache:
            return cache[(i, j)]
        
        # If characters match, no operation needed for this position
        if word1[i-1] == word2[j-1]:
            result = edit_distance_recursive(i-1, j-1)
        else:
            
            # Try all three operations and pick the minimum
            # Replace: Replace word1[i-1] with word2[j-1]
            replace_op = 1 + edit_distance_recursive(i-1, j-1)
            
            # Delete: Delete word1[i-1]
            delete_op = 1 + edit_distance_recursive(i-1, j)
            
            # Insert: Insert word2[j-1] into word1
            insert_op = 1 + edit_distance_recursive(i, j-1)
            
            # Take minimum of the three operations
            result = min(replace_op, delete_op, insert_op)
        
        # cache result    
        cache[(i, j)] = result
        return result
    
    return edit_distance_recursive(len(word1), len(word2))

# %%
# Test case 1
word1_1 = "horse"
word2_1 = "ros"
print("Question 2: Edit Distance")
print(f"Example 1: Minimum operations to convert '{word1_1}' to '{word2_1}': {min_distance(word1_1, word2_1)}")

# Test case 2
word1_2 = "intention"
word2_2 = "execution"
print(f"Example 2: Minimum operations to convert '{word1_2}' to '{word2_2}': {min_distance(word1_2, word2_2)}")
# Out:
# Question 2: Edit Distance
# Example 1: Minimum operations to convert 'horse' to 'ros': 3
# Example 2: Minimum operations to convert 'intention' to 'execution': 5

# %% [markdown]
# **Edit Distance Algorithm Explanation**:
# The edit distance (also known as Levenshtein distance) is the minimum number of operations required to convert one string to another, where the allowed operations are:
# 1. Insert a character
# 2. Delete a character
# 3. Replace a character
#
# The recursive solution with memoization works as follows:
# Base Cases:
# - If word1 is empty (i=0), return j (insert all characters of word2)
# - If word2 is empty (j=0), return i (delete all characters of word1)
#
# Recursive Case:
# 1. If the current characters match (word1[i-1] == word2[j-1]), no operation is needed for this position, so recur for the remaining strings: edit_distance(i-1, j-1)
# 2. If they don't match, try all three operations and take the minimum:
#    - Replace: 1 + edit_distance(i-1, j-1)
#    - Delete: 1 + edit_distance(i-1, j)
#    - Insert: 1 + edit_distance(i, j-1)
#
#
# - The time complexity would be O(3^(m+n)) without memoization, but with memoization, it's reduced to O(m*n) where m and n are the lengths of the two strings. Space complexity is O(m*n) for the cache plus O(m+n) for the recursion stack.
# - This is a classic dynamic programming problem, and the recursive memoization approach elegantly captures the optimal substructure of the problem.

# %% [markdown]
# ### Question-03: Print the max value of the array [13, 1, -3, 22, 5]

# %%
def max_value(arr, start= 0, end= None):
    """
    Find the maximum value in array using recursion.

    Args:
        arr: Input array
        start: Start Index
        end: End index (len(arr) - 1)
    """
    
    if end is None:
        end = len(arr) - 1
    
    # Base case: If there's only one element
    if start == end:
        return arr[start]
    
    # Recursive case: Find max of current element and max of rest of the array
    return max(arr[start], max_value(arr, start + 1, end))

# Test array
arr3 = [13, 1, -3, 22, 5]
print("Question 3: Find Maximum Value")
print(f"Maximum value in {arr3}: {max_value(arr3)}")
# Out:
# Question 3: Find Maximum Value
# Maximum value in [13, 1, -3, 22, 5]: 22

# %% [markdown]
# **Find Maximum Value Algorithm Explanation**:
# This recursive function finds the maximum value in an array by comparing each element with the maximum of the remaining elements. The recursive approach is:
#
# Base Case:
# - If there's only one element in the array (start == end), return that element.
#
# Recursive Case:
# - Compare the current element (arr[start]) with the maximum of the rest of the array (find_max(arr, start + 1, end)) and return the larger value.
#
# - Time Complexity: O(n) where n is the length of the array, as each element is processed once. Space Complexity: O(n) due to the recursion call stack.
# This is a straightforward application of recursion for array processing. While not the most efficient solution (an iterative approach would use O(1) space), it demonstrates the power of recursive thinking for array operations.

# %% [markdown]
# ### Question-04: Find the sum of the values of the array [92, 23, 15, -20, 10].

# %%
def array_sum(arr, start=0, end=None):
    """
    Calculate the sum of all values in an array using recursion
    
    Parameters:
    arr: Input array
    start: Start index (default 0)
    end: End index (default len(arr)-1)
    
    Returns: Sum of all elements in the array
    """
    if end is None:
        end = len(arr) - 1
    
    # Base case: If there's only one element
    if start == end:
        return arr[start]
    
    # Recursive case: Add current element to sum of rest of the array
    return arr[start] + array_sum(arr, start + 1, end)


# Test array
arr4 = [92, 23, 15, -20, 10]
print("Question 4: Calculate Array Sum")
print(f"Sum of values in {arr4}: {array_sum(arr4)}")
# Out:
# Question 4: Calculate Array Sum
# Sum of values in [92, 23, 15, -20, 10]: 120

# %% [markdown]
# ##### Q.5 Given a number n. Print if it is an armstrong number or not.An armstrong number is a number if the sum of every digit in that number raised to the power of total digits in that number is equal to the number.
# - Example : 153 = 1^3 + 5^3 + 3^3 = 1 + 125 + 27 = 153 hence 153 is an armstrong number. (Easy)

# %%
def is_armstrong_number(num):
    """
    Check if a number is an Armstrong number
    An Armstrong number is a number if the sum of each digit raised to the 
    power of the total number of digits equals the original number
    
    Parameters:
    num: The number to check
    
    Returns: True if num is an Armstrong number, False otherwise
    """
    # Convert number to string to count digits
    num_str = str(num)
    n = len(num_str)
    
    def sum_of_powers(num_str, power, index=0):
        # Base case: Reached the end of the string
        if index == len(num_str):
            return 0
        
        # Recursive case: Current digit raised to power + sum of the rest
        current_digit = int(num_str[index])
        return (current_digit ** power) + sum_of_powers(num_str, power, index + 1)
    
    # Check if the sum of powers equals the original number
    return sum_of_powers(num_str, n) == num

# Test cases
test_nums = [153, 134]
print("Question 5: Check Armstrong Number")
for num in test_nums:
    result = "Yes" if is_armstrong_number(num) else "No"
    print(f"Is {num} an Armstrong number? {result}")
    
    # Verification for clarity
    num_str = str(num)
    n = len(num_str)
    sum_powers = sum(int(digit) ** n for digit in num_str)
    print(f"Verification: Sum of each digit^{n} = {sum_powers}")
# Out:
# Question 5: Check Armstrong Number
# Is 153 an Armstrong number? Yes
# Verification: Sum of each digit^3 = 153
# Is 134 an Armstrong number? No
# Verification: Sum of each digit^3 = 92

# %% [markdown]
# **Armstrong Number Check Algorithm Explanation**:
# An Armstrong number (also known as a narcissistic number) is a number that equals the sum of its digits each raised to the power of the number of digits.
# The recursive approach to check for Armstrong numbers has two main parts:
# 1. Count the number of digits in the number (n)
# 2. Calculate the sum of each digit raised to the power of n
#
# Base Case:
# - If we've processed all digits (index == length of num_str), return 0.
#
# Recursive Case:
# - Take the current digit, raise it to the power of n, and add it to the sum of
#   powers for the remaining digits.
#
# Time Complexity: O(d) where d is the number of digits in the input number.
# Space Complexity: O(d) due to the recursion call stack.
#
# - This problem demonstrates how recursion can be used to process individual digits of a number. The recursive function elegantly breaks down the task of calculating the sum of powers by handling one digit at a time.
#
# Examples:
# - 153 is an Armstrong number because 1^3 + 5^3 + 3^3 = 1 + 125 + 27 = 153
# - 134 is not an Armstrong number because 1^3 + 3^3 + 4^3 = 1 + 27 + 64 = 92 ≠ 134

# %%
print("Summary of Recursive Solutions:")
print("1. Tower of Hanoi: A classic problem demonstrating divide and conquer recursion")
print("2. Edit Distance: An optimal substructure problem showing recursive dynamic programming")
print("3. Find Max: Simple linear recursion for array processing")
print("4. Array Sum: Another example of linear recursion for aggregation")
print("5. Armstrong Number: Recursion to process individual digits of a number")
print("\nAll solutions showcase the power of recursion in breaking down complex problems into simpler subproblems.")
# Out:
# Summary of Recursive Solutions:
# 1. Tower of Hanoi: A classic problem demonstrating divide and conquer recursion
# 2. Edit Distance: An optimal substructure problem showing recursive dynamic programming
# 3. Find Max: Simple linear recursion for array processing
# 4. Array Sum: Another example of linear recursion for aggregation
# 5. Armstrong Number: Recursion to process individual digits of a number
#
# All solutions showcase the power of recursion in breaking down complex problems into simpler subproblems.
